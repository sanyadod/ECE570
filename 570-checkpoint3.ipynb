# %%
# Cell 1: Reproducing BYOL on CIFAR-10 with Detailed Print Statements

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torchvision.models import resnet18
import copy
import time

print("Starting Cell 1: Fully reproduce BYOL on CIFAR-10...")

# Define a transform that will generate two differently augmented views.
class TwoCropsTransform:
    def __init__(self, base_transform):
        self.base_transform = base_transform

    def __call__(self, x):
        return [self.base_transform(x), self.base_transform(x)]

# Define our data augmentation pipeline (similar to that used in BYOL).
base_augmentation = transforms.Compose([
    transforms.RandomResizedCrop(size=32),
    transforms.RandomHorizontalFlip(),
    transforms.RandomApply([transforms.ColorJitter(0.4, 0.4, 0.4, 0.1)], p=0.8),
    transforms.RandomGrayscale(p=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.4914, 0.4822, 0.4465),
                         std=(0.2023, 0.1994, 0.2010))
])
# Wrap the transform to get two augmented copies.
transform_train = TwoCropsTransform(base_augmentation)

# Load the CIFAR-10 training dataset.
train_dataset = torchvision.datasets.CIFAR10(root='./data',
                                             train=True,
                                             download=True,
                                             transform=transform_train)
print(f"Loaded CIFAR-10 training dataset with {len(train_dataset)} samples.")
train_loader = torch.utils.data.DataLoader(train_dataset,
                                           batch_size=128,
                                           shuffle=True,
                                           num_workers=2)

# --- Model Components ---

# MLP definition for both the projector and predictor.
class MLP(nn.Module):
    def __init__(self, in_dim, hidden_dim, out_dim):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(in_dim, hidden_dim)
        self.relu = nn.ReLU(inplace=True)
        self.fc2 = nn.Linear(hidden_dim, out_dim)

    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))

# Modify the ResNet-18 to output a feature vector (remove the final FC layer).
class ResNet18Feature(nn.Module):
    def __init__(self):
        super(ResNet18Feature, self).__init__()
        self.resnet = resnet18(pretrained=False)
        # Remove the final classification layer: take all layers except the last fully connected.
        self.features = nn.Sequential(*list(self.resnet.children())[:-1])
        self.fc_dim = 512  # output dimension for resnet18

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        return x

# Define the BYOL model which assembles encoder, projector, and predictor.
class BYOL(nn.Module):
    def __init__(self, base_encoder):
        super(BYOL, self).__init__()
        self.encoder = base_encoder
        self.projector = MLP(in_dim=base_encoder.fc_dim, hidden_dim=256, out_dim=256)
        self.predictor = MLP(in_dim=256, hidden_dim=256, out_dim=256)

    def forward(self, x):
        features = self.encoder(x)
        proj = self.projector(features)
        pred = self.predictor(proj)
        return features, proj, pred

# Setup devices and instantiate our online and target networks.
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Using device:", device)

# Online network instantiation.
online_encoder = ResNet18Feature().to(device)
online_model = BYOL(online_encoder).to(device)
print("Initialized online BYOL model.")

# Target network: a deep copy of the online components (without the predictor).
target_encoder = copy.deepcopy(online_encoder).to(device)
target_projector = copy.deepcopy(online_model.projector).to(device)
target_encoder.eval()
target_projector.eval()
print("Initialized target encoder and projector (set to eval mode).")

# Optimizer for the online network (including encoder, projector, and predictor).
optimizer = optim.SGD(online_model.parameters(), lr=0.03, momentum=0.9, weight_decay=5e-4)
print("Optimizer initialized for online network.")

# Function to update target network parameters using exponential moving average (EMA).
def update_moving_average(online_net, target_net, momentum):
    for param_o, param_t in zip(online_net.parameters(), target_net.parameters()):
        param_t.data = param_t.data * momentum + param_o.data * (1.0 - momentum)

# --- Training Loop for BYOL ---
epochs = 10  # (For demonstration purposes; increase this for real experiments)
ema_momentum = 0.996  # Momentum coefficient for target updates

print("Starting BYOL training...")
for epoch in range(epochs):
    online_model.train()
    running_loss = 0.0
    start_time = time.time()

    for batch_idx, (images, _) in enumerate(train_loader):
        # Each 'images' is a list of two augmented views.
        view1, view2 = images[0].to(device), images[1].to(device)
        optimizer.zero_grad()

        # Debug: Print shapes of input views.
        if batch_idx == 0:
            print(f"Epoch {epoch+1}: First batch view1 shape: {view1.shape}, view2 shape: {view2.shape}")

        # First branch: online network processes view1.
        _, proj1, pred1 = online_model(view1)
        # Target network processes view2 (no gradients).
        with torch.no_grad():
            feat2 = target_encoder(view2)
            proj2 = target_projector(feat2)

        # Normalize before computing mean-squared error.
        pred1_norm = F.normalize(pred1, dim=1)
        proj2_norm = F.normalize(proj2, dim=1)
        loss1 = F.mse_loss(pred1_norm, proj2_norm)

        # Second branch: swap views.
        _, proj2_online, pred2 = online_model(view2)
        with torch.no_grad():
            feat1 = target_encoder(view1)
            proj1_target = target_projector(feat1)
        pred2_norm = F.normalize(pred2, dim=1)
        proj1_target_norm = F.normalize(proj1_target, dim=1)
        loss2 = F.mse_loss(pred2_norm, proj1_target_norm)

        loss = loss1 + loss2
        loss.backward()
        optimizer.step()

        # Update target network weights with EMA.
        update_moving_average(online_encoder, target_encoder, ema_momentum)
        update_moving_average(online_model.projector, target_projector, ema_momentum)

        running_loss += loss.item() * view1.size(0)

        # Print progress every 50 batches.
        if (batch_idx + 1) % 50 == 0:
            print(f"Epoch {epoch+1} Batch {batch_idx+1}: Loss1={loss1.item():.4f}, Loss2={loss2.item():.4f}")

    epoch_loss = running_loss / len(train_loader.dataset)
    elapsed = time.time() - start_time
    print(f"Completed Epoch {epoch+1}: Avg Loss: {epoch_loss:.4f}, Time: {elapsed:.2f}s")

print("BYOL training finished on CIFAR-10.")
# Out:
# Starting Cell 1: Fully reproduce BYOL on CIFAR-10...
# Loaded CIFAR-10 training dataset with 50000 samples.
# Using device: cuda
# Initialized online BYOL model.
# Initialized target encoder and projector (set to eval mode).
# Optimizer initialized for online network.
# Starting BYOL training...
# Epoch 1: First batch view1 shape: torch.Size([128, 3, 32, 32]), view2 shape: torch.Size([128, 3, 32, 32])
# Epoch 1 Batch 50: Loss1=0.0030, Loss2=0.0031
# Epoch 1 Batch 100: Loss1=0.0015, Loss2=0.0015
# Epoch 1 Batch 150: Loss1=0.0010, Loss2=0.0010
# Epoch 1 Batch 200: Loss1=0.0007, Loss2=0.0007
# Epoch 1 Batch 250: Loss1=0.0006, Loss2=0.0006
# Epoch 1 Batch 300: Loss1=0.0005, Loss2=0.0005
# Epoch 1 Batch 350: Loss1=0.0005, Loss2=0.0005
# Completed Epoch 1: Avg Loss: 0.0028, Time: 83.94s
# Epoch 2: First batch view1 shape: torch.Size([128, 3, 32, 32]), view2 shape: torch.Size([128, 3, 32, 32])
# Epoch 2 Batch 50: Loss1=0.0004, Loss2=0.0004
# Epoch 2 Batch 100: Loss1=0.0003, Loss2=0.0004
# Epoch 2 Batch 150: Loss1=0.0003, Loss2=0.0003
# Epoch 2 Batch 200: Loss1=0.0003, Loss2=0.0003
# Epoch 2 Batch 250: Loss1=0.0003, Loss2=0.0003
# Epoch 2 Batch 300: Loss1=0.0003, Loss2=0.0003
# Epoch 2 Batch 350: Loss1=0.0003, Loss2=0.0003
# Completed Epoch 2: Avg Loss: 0.0007, Time: 81.93s
# Epoch 3: First batch view1 shape: torch.Size([128, 3, 32, 32]), view2 shape: torch.Size([128, 3, 32, 32])
# Epoch 3 Batch 50: Loss1=0.0003, Loss2=0.0002
# Epoch 3 Batch 100: Loss1=0.0002, Loss2=0.0002
# Epoch 3 Batch 150: Loss1=0.0002, Loss2=0.0002
# Epoch 3 Batch 200: Loss1=0.0002, Loss2=0.0002
# Epoch 3 Batch 250: Loss1=0.0002, Loss2=0.0002
# Epoch 3 Batch 300: Loss1=0.0002, Loss2=0.0002
# Epoch 3 Batch 350: Loss1=0.0002, Loss2=0.0002
# Completed Epoch 3: Avg Loss: 0.0004, Time: 84.29s
# Epoch 4: First batch view1 shape: torch.Size([128, 3, 32, 32]), view2 shape: torch.Size([128, 3, 32, 32])
# Epoch 4 Batch 50: Loss1=0.0001, Loss2=0.0001
# Epoch 4 Batch 100: Loss1=0.0001, Loss2=0.0001
# Epoch 4 Batch 150: Loss1=0.0001, Loss2=0.0001
# Epoch 4 Batch 200: Loss1=0.0001, Loss2=0.0001
# Epoch 4 Batch 250: Loss1=0.0001, Loss2=0.0001
# Epoch 4 Batch 300: Loss1=0.0001, Loss2=0.0001
# Epoch 4 Batch 350: Loss1=0.0001, Loss2=0.0001
# Completed Epoch 4: Avg Loss: 0.0002, Time: 82.02s
# Epoch 5: First batch view1 shape: torch.Size([128, 3, 32, 32]), view2 shape: torch.Size([128, 3, 32, 32])
# Epoch 5 Batch 50: Loss1=0.0001, Loss2=0.0001
# Epoch 5 Batch 100: Loss1=0.0001, Loss2=0.0001
# Epoch 5 Batch 150: Loss1=0.0000, Loss2=0.0001
# Epoch 5 Batch 200: Loss1=0.0000, Loss2=0.0000
# Epoch 5 Batch 250: Loss1=0.0000, Loss2=0.0000
# Epoch 5 Batch 300: Loss1=0.0000, Loss2=0.0000
# Epoch 5 Batch 350: Loss1=0.0000, Loss2=0.0000
# Completed Epoch 5: Avg Loss: 0.0001, Time: 83.91s
# Epoch 6: First batch view1 shape: torch.Size([128, 3, 32, 32]), view2 shape: torch.Size([128, 3, 32, 32])
# Epoch 6 Batch 50: Loss1=0.0000, Loss2=0.0000
# Epoch 6 Batch 100: Loss1=0.0000, Loss2=0.0000
# Epoch 6 Batch 150: Loss1=0.0000, Loss2=0.0000
# Epoch 6 Batch 200: Loss1=0.0000, Loss2=0.0000
# Epoch 6 Batch 250: Loss1=0.0000, Loss2=0.0000
# Epoch 6 Batch 300: Loss1=0.0000, Loss2=0.0000
# Epoch 6 Batch 350: Loss1=0.0000, Loss2=0.0000
# Completed Epoch 6: Avg Loss: 0.0001, Time: 82.46s
# Epoch 7: First batch view1 shape: torch.Size([128, 3, 32, 32]), view2 shape: torch.Size([128, 3, 32, 32])
# Epoch 7 Batch 50: Loss1=0.0000, Loss2=0.0000
# Epoch 7 Batch 100: Loss1=0.0000, Loss2=0.0000
# Epoch 7 Batch 150: Loss1=0.0000, Loss2=0.0000
# Epoch 7 Batch 200: Loss1=0.0000, Loss2=0.0000
# Epoch 7 Batch 250: Loss1=0.0000, Loss2=0.0000
# Epoch 7 Batch 300: Loss1=0.0000, Loss2=0.0000
# Epoch 7 Batch 350: Loss1=0.0000, Loss2=0.0000
# Completed Epoch 7: Avg Loss: 0.0000, Time: 83.69s
# Epoch 8: First batch view1 shape: torch.Size([128, 3, 32, 32]), view2 shape: torch.Size([128, 3, 32, 32])
# Epoch 8 Batch 50: Loss1=0.0000, Loss2=0.0000
# Epoch 8 Batch 100: Loss1=0.0000, Loss2=0.0000
# Epoch 8 Batch 150: Loss1=0.0000, Loss2=0.0000
# Epoch 8 Batch 200: Loss1=0.0000, Loss2=0.0000
# Epoch 8 Batch 250: Loss1=0.0000, Loss2=0.0000
# Epoch 8 Batch 300: Loss1=0.0000, Loss2=0.0000
# Epoch 8 Batch 350: Loss1=0.0000, Loss2=0.0000
# Completed Epoch 8: Avg Loss: 0.0000, Time: 81.98s
# Epoch 9: First batch view1 shape: torch.Size([128, 3, 32, 32]), view2 shape: torch.Size([128, 3, 32, 32])
# Epoch 9 Batch 50: Loss1=0.0000, Loss2=0.0000
# Epoch 9 Batch 100: Loss1=0.0000, Loss2=0.0000
# Epoch 9 Batch 150: Loss1=0.0000, Loss2=0.0000
# Epoch 9 Batch 200: Loss1=0.0000, Loss2=0.0000
# Epoch 9 Batch 250: Loss1=0.0000, Loss2=0.0000
# Epoch 9 Batch 300: Loss1=0.0000, Loss2=0.0000
# Epoch 9 Batch 350: Loss1=0.0000, Loss2=0.0000
# Completed Epoch 9: Avg Loss: 0.0000, Time: 81.83s
# Epoch 10: First batch view1 shape: torch.Size([128, 3, 32, 32]), view2 shape: torch.Size([128, 3, 32, 32])
# Epoch 10 Batch 50: Loss1=0.0000, Loss2=0.0000
# Epoch 10 Batch 100: Loss1=0.0000, Loss2=0.0000
# Epoch 10 Batch 150: Loss1=0.0000, Loss2=0.0000
# Epoch 10 Batch 200: Loss1=0.0000, Loss2=0.0000
# Epoch 10 Batch 250: Loss1=0.0000, Loss2=0.0000
# Epoch 10 Batch 300: Loss1=0.0000, Loss2=0.0000
# Epoch 10 Batch 350: Loss1=0.0000, Loss2=0.0000
# Completed Epoch 10: Avg Loss: 0.0000, Time: 82.64s
# BYOL training finished on CIFAR-10.

# %%
# Cell 2: Semi-Supervised BYOL with a Small Fraction of Labeled Data including detailed print statements

import numpy as np
from torch.utils.data import Subset, DataLoader

print("\nStarting Cell 2: Semi-Supervised BYOL...")

# Define a simple classifier head to attach to our encoder.
class ClassifierHead(nn.Module):
    def __init__(self, in_dim, num_classes=10):
        super(ClassifierHead, self).__init__()
        self.fc = nn.Linear(in_dim, num_classes)

    def forward(self, x):
        return self.fc(x)

# We reuse the previously defined ResNet18Feature and BYOL model.
# Here we add a classification head to the online encoder.
class SemiSupervisedBYOL(nn.Module):
    def __init__(self, base_encoder, num_classes=10):
        super(SemiSupervisedBYOL, self).__init__()
        self.encoder = base_encoder  # shared encoder
        self.projector = MLP(in_dim=base_encoder.fc_dim, hidden_dim=256, out_dim=256)
        self.predictor = MLP(in_dim=256, hidden_dim=256, out_dim=256)
        # Classification head for supervised learning.
        self.classifier = ClassifierHead(in_dim=base_encoder.fc_dim, num_classes=num_classes)

    def forward(self, x):
        features = self.encoder(x)
        proj = self.projector(features)
        pred = self.predictor(proj)
        logits = self.classifier(features)
        return features, proj, pred, logits

# Create a labeled split (10% of CIFAR-10 training data).
all_indices = np.arange(len(train_dataset))
np.random.seed(42)  # for reproducibility
labeled_indices = np.random.choice(all_indices, size=int(0.1 * len(train_dataset)), replace=False)
unlabeled_indices = np.setdiff1d(all_indices, labeled_indices)
print(f"Total samples: {len(train_dataset)}, Labeled: {len(labeled_indices)}, Unlabeled: {len(unlabeled_indices)}")

# For the labeled dataset we will use a standard transform for classification (without double augmentation).
transform_labeled = transforms.Compose([
    transforms.RandomResizedCrop(32),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.4914, 0.4822, 0.4465),
                         std=(0.2023, 0.1994, 0.2010))
])
# Create labeled and unlabeled subsets.
labeled_dataset = Subset(torchvision.datasets.CIFAR10(root='./data', train=True,
                                                      download=False,
                                                      transform=transform_labeled),
                         labeled_indices)
# Unlabeled dataset still uses two-crop transform.
unlabeled_dataset = Subset(train_dataset, unlabeled_indices)
print("Created labeled and unlabeled datasets.")

# Define dataloaders for both.
labeled_loader = DataLoader(labeled_dataset, batch_size=64, shuffle=True, num_workers=2)
unlabeled_loader = DataLoader(unlabeled_dataset, batch_size=128, shuffle=True, num_workers=2)

# Instantiate the semi-supervised BYOL model.
base_encoder_ss = ResNet18Feature().to(device)
semi_supervised_model = SemiSupervisedBYOL(base_encoder_ss).to(device)
print("Initialized semi-supervised BYOL model with classifier head.")

# Copy target network components for the unsupervised loss (EMA updates only on encoder and projector).
target_encoder_ss = copy.deepcopy(base_encoder_ss).to(device)
target_projector_ss = copy.deepcopy(semi_supervised_model.projector).to(device)
target_encoder_ss.eval()
target_projector_ss.eval()
print("Initialized target network for semi-supervised branch.")

# Optimizer covers all parameters (encoder, projector, predictor, and classification head).
optimizer_ss = optim.SGD(semi_supervised_model.parameters(), lr=0.03, momentum=0.9, weight_decay=5e-4)
criterion_supervised = nn.CrossEntropyLoss()
lambda_sup = 1.0  # Weighting coefficient for the supervised loss

# Training loop for semi-supervised learning.
epochs_ss = 10
print("Starting semi-supervised training...")
for epoch in range(epochs_ss):
    semi_supervised_model.train()
    running_loss = 0.0
    running_sup_loss = 0.0
    start_time = time.time()

    unlabeled_iter = iter(unlabeled_loader)
    labeled_iter = iter(labeled_loader)

    num_iterations = len(unlabeled_loader)
    print(f"Epoch {epoch+1}/{epochs_ss} with {num_iterations} iterations.")

    for iter_idx in range(num_iterations):
        # --- Unsupervised BYOL branch on unlabeled data ---
        try:
            images_unlab, _ = next(unlabeled_iter)
        except StopIteration:
            unlabeled_iter = iter(unlabeled_loader)
            images_unlab, _ = next(unlabeled_iter)
        view1, view2 = images_unlab[0].to(device), images_unlab[1].to(device)

        # Forward pass for unsupervised branch.
        _, proj1, pred1, _ = semi_supervised_model(view1)
        with torch.no_grad():
            feat2 = target_encoder_ss(view2)
            proj2 = target_projector_ss(feat2)
        loss1 = F.mse_loss(F.normalize(pred1, dim=1), F.normalize(proj2, dim=1))

        _, proj2_online, pred2, _ = semi_supervised_model(view2)
        with torch.no_grad():
            feat1 = target_encoder_ss(view1)
            proj1_target = target_projector_ss(feat1)
        loss2 = F.mse_loss(F.normalize(pred2, dim=1), F.normalize(proj1_target, dim=1))
        loss_unsupervised = loss1 + loss2

        # --- Supervised branch on labeled data ---
        try:
            images_lab, labels_lab = next(labeled_iter)
        except StopIteration:
            labeled_iter = iter(labeled_loader)
            images_lab, labels_lab = next(labeled_iter)
        images_lab = images_lab.to(device)
        labels_lab = labels_lab.to(device)
        _, _, _, logits = semi_supervised_model(images_lab)
        loss_supervised = criterion_supervised(logits, labels_lab)

        # Total loss: weighted sum of unsupervised and supervised parts.
        total_loss = loss_unsupervised + lambda_sup * loss_supervised

        optimizer_ss.zero_grad()
        total_loss.backward()
        optimizer_ss.step()

        # EMA update for target network components.
        update_moving_average(semi_supervised_model.encoder, target_encoder_ss, ema_momentum)
        update_moving_average(semi_supervised_model.projector, target_projector_ss, ema_momentum)

        running_loss += total_loss.item()
        running_sup_loss += loss_supervised.item()

        # Detailed print on every 20 iterations.
        if (iter_idx + 1) % 20 == 0:
            print(f"Epoch {epoch+1} Iteration {iter_idx+1}: "
                  f"Unsup Loss={loss_unsupervised.item():.4f}, Sup Loss={loss_supervised.item():.4f}, Total Loss={total_loss.item():.4f}")

    avg_loss = running_loss / num_iterations
    avg_sup_loss = running_sup_loss / num_iterations
    elapsed = time.time() - start_time
    print(f"Epoch {epoch+1} complete: Avg Total Loss: {avg_loss:.4f}, Avg Sup Loss: {avg_sup_loss:.4f}, Time: {elapsed:.2f}s")

print("Semi-supervised BYOL training finished.")
# Out:
# Starting Cell 2: Semi-Supervised BYOL...
# Total samples: 50000, Labeled: 5000, Unlabeled: 45000
# Created labeled and unlabeled datasets.
# Initialized semi-supervised BYOL model with classifier head.
# Initialized target network for semi-supervised branch.
# Starting semi-supervised training...
# Epoch 1/10 with 352 iterations.
# Epoch 1 Iteration 20: Unsup Loss=0.0126, Sup Loss=2.7380, Total Loss=2.7507
# Epoch 1 Iteration 40: Unsup Loss=0.0087, Sup Loss=3.0002, Total Loss=3.0089
# Epoch 1 Iteration 60: Unsup Loss=0.0065, Sup Loss=2.7076, Total Loss=2.7141
# Epoch 1 Iteration 80: Unsup Loss=0.0048, Sup Loss=2.4383, Total Loss=2.4431
# Epoch 1 Iteration 100: Unsup Loss=0.0035, Sup Loss=2.4945, Total Loss=2.4981
# Epoch 1 Iteration 120: Unsup Loss=0.0027, Sup Loss=2.2127, Total Loss=2.2154
# Epoch 1 Iteration 140: Unsup Loss=0.0022, Sup Loss=2.0711, Total Loss=2.0733
# Epoch 1 Iteration 160: Unsup Loss=0.0018, Sup Loss=2.6915, Total Loss=2.6933
# Epoch 1 Iteration 180: Unsup Loss=0.0016, Sup Loss=2.1905, Total Loss=2.1922
# Epoch 1 Iteration 200: Unsup Loss=0.0015, Sup Loss=2.2099, Total Loss=2.2114
# Epoch 1 Iteration 220: Unsup Loss=0.0014, Sup Loss=2.2120, Total Loss=2.2134
# Epoch 1 Iteration 240: Unsup Loss=0.0013, Sup Loss=2.4217, Total Loss=2.4230
# Epoch 1 Iteration 260: Unsup Loss=0.0011, Sup Loss=2.0153, Total Loss=2.0164
# Epoch 1 Iteration 280: Unsup Loss=0.0010, Sup Loss=1.8605, Total Loss=1.8615
# Epoch 1 Iteration 300: Unsup Loss=0.0009, Sup Loss=1.8269, Total Loss=1.8278
# Epoch 1 Iteration 320: Unsup Loss=0.0008, Sup Loss=2.2873, Total Loss=2.2881
# Epoch 1 Iteration 340: Unsup Loss=0.0007, Sup Loss=2.0512, Total Loss=2.0519
# Epoch 1 complete: Avg Total Loss: 2.3527, Avg Sup Loss: 2.3493, Time: 90.14s
# Epoch 2/10 with 352 iterations.
# Epoch 2 Iteration 20: Unsup Loss=0.0006, Sup Loss=2.1787, Total Loss=2.1794
# Epoch 2 Iteration 40: Unsup Loss=0.0005, Sup Loss=1.8131, Total Loss=1.8136
# Epoch 2 Iteration 60: Unsup Loss=0.0005, Sup Loss=1.7603, Total Loss=1.7609
# Epoch 2 Iteration 80: Unsup Loss=0.0005, Sup Loss=1.8804, Total Loss=1.8810
# Epoch 2 Iteration 100: Unsup Loss=0.0005, Sup Loss=2.4931, Total Loss=2.4936
# Epoch 2 Iteration 120: Unsup Loss=0.0005, Sup Loss=2.2836, Total Loss=2.2841
# Epoch 2 Iteration 140: Unsup Loss=0.0004, Sup Loss=1.8408, Total Loss=1.8412
# Epoch 2 Iteration 160: Unsup Loss=0.0004, Sup Loss=1.7825, Total Loss=1.7828
# Epoch 2 Iteration 180: Unsup Loss=0.0003, Sup Loss=1.8983, Total Loss=1.8987
# Epoch 2 Iteration 200: Unsup Loss=0.0003, Sup Loss=1.9854, Total Loss=1.9857
# Epoch 2 Iteration 220: Unsup Loss=0.0003, Sup Loss=1.8746, Total Loss=1.8750
# Epoch 2 Iteration 240: Unsup Loss=0.0003, Sup Loss=1.9794, Total Loss=1.9797
# Epoch 2 Iteration 260: Unsup Loss=0.0003, Sup Loss=2.0000, Total Loss=2.0003
# Epoch 2 Iteration 280: Unsup Loss=0.0004, Sup Loss=1.8985, Total Loss=1.8989
# Epoch 2 Iteration 300: Unsup Loss=0.0004, Sup Loss=1.9111, Total Loss=1.9115
# Epoch 2 Iteration 320: Unsup Loss=0.0005, Sup Loss=2.0815, Total Loss=2.0820
# Epoch 2 Iteration 340: Unsup Loss=0.0004, Sup Loss=1.9412, Total Loss=1.9416
# Epoch 2 complete: Avg Total Loss: 1.9985, Avg Sup Loss: 1.9980, Time: 91.28s
# Epoch 3/10 with 352 iterations.
# Epoch 3 Iteration 20: Unsup Loss=0.0004, Sup Loss=1.6675, Total Loss=1.6679
# Epoch 3 Iteration 40: Unsup Loss=0.0003, Sup Loss=1.7919, Total Loss=1.7923
# Epoch 3 Iteration 60: Unsup Loss=0.0003, Sup Loss=2.0141, Total Loss=2.0144
# Epoch 3 Iteration 80: Unsup Loss=0.0003, Sup Loss=1.7203, Total Loss=1.7205
# Epoch 3 Iteration 100: Unsup Loss=0.0002, Sup Loss=2.0371, Total Loss=2.0374
# Epoch 3 Iteration 120: Unsup Loss=0.0002, Sup Loss=1.9830, Total Loss=1.9832
# Epoch 3 Iteration 140: Unsup Loss=0.0002, Sup Loss=1.7486, Total Loss=1.7488
# Epoch 3 Iteration 160: Unsup Loss=0.0001, Sup Loss=1.9289, Total Loss=1.9290
# Epoch 3 Iteration 180: Unsup Loss=0.0001, Sup Loss=1.6754, Total Loss=1.6756
# Epoch 3 Iteration 200: Unsup Loss=0.0001, Sup Loss=1.7084, Total Loss=1.7086
# Epoch 3 Iteration 220: Unsup Loss=0.0001, Sup Loss=1.8794, Total Loss=1.8795
# Epoch 3 Iteration 240: Unsup Loss=0.0001, Sup Loss=1.7557, Total Loss=1.7558
# Epoch 3 Iteration 260: Unsup Loss=0.0001, Sup Loss=1.8747, Total Loss=1.8748
# Epoch 3 Iteration 280: Unsup Loss=0.0001, Sup Loss=1.7108, Total Loss=1.7108
# Epoch 3 Iteration 300: Unsup Loss=0.0001, Sup Loss=1.9757, Total Loss=1.9758
# Epoch 3 Iteration 320: Unsup Loss=0.0001, Sup Loss=1.8953, Total Loss=1.8953
# Epoch 3 Iteration 340: Unsup Loss=0.0001, Sup Loss=1.9446, Total Loss=1.9446
# Epoch 3 complete: Avg Total Loss: 1.8657, Avg Sup Loss: 1.8655, Time: 91.21s
# Epoch 4/10 with 352 iterations.
# Epoch 4 Iteration 20: Unsup Loss=0.0001, Sup Loss=1.6428, Total Loss=1.6429
# Epoch 4 Iteration 40: Unsup Loss=0.0001, Sup Loss=1.7889, Total Loss=1.7890
# Epoch 4 Iteration 60: Unsup Loss=0.0001, Sup Loss=2.0546, Total Loss=2.0547
# Epoch 4 Iteration 80: Unsup Loss=0.0001, Sup Loss=2.0542, Total Loss=2.0543
# Epoch 4 Iteration 100: Unsup Loss=0.0001, Sup Loss=1.6993, Total Loss=1.6994
# Epoch 4 Iteration 120: Unsup Loss=0.0001, Sup Loss=1.5530, Total Loss=1.5531
# Epoch 4 Iteration 140: Unsup Loss=0.0001, Sup Loss=1.8552, Total Loss=1.8553
# Epoch 4 Iteration 160: Unsup Loss=0.0001, Sup Loss=1.9454, Total Loss=1.9455
# Epoch 4 Iteration 180: Unsup Loss=0.0001, Sup Loss=1.7827, Total Loss=1.7828
# Epoch 4 Iteration 200: Unsup Loss=0.0001, Sup Loss=1.6254, Total Loss=1.6255
# Epoch 4 Iteration 220: Unsup Loss=0.0001, Sup Loss=1.7720, Total Loss=1.7721
# Epoch 4 Iteration 240: Unsup Loss=0.0001, Sup Loss=1.8605, Total Loss=1.8606
# Epoch 4 Iteration 260: Unsup Loss=0.0001, Sup Loss=1.7426, Total Loss=1.7426
# Epoch 4 Iteration 280: Unsup Loss=0.0001, Sup Loss=1.8352, Total Loss=1.8352
# Epoch 4 Iteration 300: Unsup Loss=0.0000, Sup Loss=1.6132, Total Loss=1.6132
# Epoch 4 Iteration 320: Unsup Loss=0.0001, Sup Loss=1.5167, Total Loss=1.5167
# Epoch 4 Iteration 340: Unsup Loss=0.0000, Sup Loss=1.6503, Total Loss=1.6503
# Epoch 4 complete: Avg Total Loss: 1.7389, Avg Sup Loss: 1.7389, Time: 90.70s
# Epoch 5/10 with 352 iterations.
# Epoch 5 Iteration 20: Unsup Loss=0.0000, Sup Loss=1.5228, Total Loss=1.5229
# Epoch 5 Iteration 40: Unsup Loss=0.0000, Sup Loss=1.6232, Total Loss=1.6232
# Epoch 5 Iteration 60: Unsup Loss=0.0000, Sup Loss=1.5392, Total Loss=1.5392
# Epoch 5 Iteration 80: Unsup Loss=0.0000, Sup Loss=1.5768, Total Loss=1.5768
# Epoch 5 Iteration 100: Unsup Loss=0.0000, Sup Loss=1.7635, Total Loss=1.7636
# Epoch 5 Iteration 120: Unsup Loss=0.0000, Sup Loss=1.4870, Total Loss=1.4871
# Epoch 5 Iteration 140: Unsup Loss=0.0000, Sup Loss=1.6244, Total Loss=1.6244
# Epoch 5 Iteration 160: Unsup Loss=0.0000, Sup Loss=1.5457, Total Loss=1.5457
# Epoch 5 Iteration 180: Unsup Loss=0.0000, Sup Loss=1.4568, Total Loss=1.4569
# Epoch 5 Iteration 200: Unsup Loss=0.0000, Sup Loss=1.7730, Total Loss=1.7730
# Epoch 5 Iteration 220: Unsup Loss=0.0001, Sup Loss=1.7670, Total Loss=1.7670
# Epoch 5 Iteration 240: Unsup Loss=0.0001, Sup Loss=1.6847, Total Loss=1.6848
# Epoch 5 Iteration 260: Unsup Loss=0.0001, Sup Loss=1.7409, Total Loss=1.7410
# Epoch 5 Iteration 280: Unsup Loss=0.0001, Sup Loss=1.8182, Total Loss=1.8182
# Epoch 5 Iteration 300: Unsup Loss=0.0000, Sup Loss=1.6394, Total Loss=1.6395
# Epoch 5 Iteration 320: Unsup Loss=0.0000, Sup Loss=1.4419, Total Loss=1.4420
# Epoch 5 Iteration 340: Unsup Loss=0.0000, Sup Loss=1.6020, Total Loss=1.6020
# Epoch 5 complete: Avg Total Loss: 1.6598, Avg Sup Loss: 1.6597, Time: 91.80s
# Epoch 6/10 with 352 iterations.
# Epoch 6 Iteration 20: Unsup Loss=0.0000, Sup Loss=1.6754, Total Loss=1.6754
# Epoch 6 Iteration 40: Unsup Loss=0.0000, Sup Loss=1.6308, Total Loss=1.6309
# Epoch 6 Iteration 60: Unsup Loss=0.0001, Sup Loss=1.6334, Total Loss=1.6335
# Epoch 6 Iteration 80: Unsup Loss=0.0000, Sup Loss=1.4585, Total Loss=1.4585
# Epoch 6 Iteration 100: Unsup Loss=0.0000, Sup Loss=1.5872, Total Loss=1.5872
# Epoch 6 Iteration 120: Unsup Loss=0.0001, Sup Loss=1.3951, Total Loss=1.3952
# Epoch 6 Iteration 140: Unsup Loss=0.0001, Sup Loss=1.4159, Total Loss=1.4160
# Epoch 6 Iteration 160: Unsup Loss=0.0000, Sup Loss=1.2685, Total Loss=1.2686
# Epoch 6 Iteration 180: Unsup Loss=0.0000, Sup Loss=1.6452, Total Loss=1.6452
# Epoch 6 Iteration 200: Unsup Loss=0.0001, Sup Loss=1.7125, Total Loss=1.7125
# Epoch 6 Iteration 220: Unsup Loss=0.0000, Sup Loss=1.5932, Total Loss=1.5933
# Epoch 6 Iteration 240: Unsup Loss=0.0000, Sup Loss=1.6798, Total Loss=1.6799
# Epoch 6 Iteration 260: Unsup Loss=0.0000, Sup Loss=1.5348, Total Loss=1.5349
# Epoch 6 Iteration 280: Unsup Loss=0.0000, Sup Loss=1.6408, Total Loss=1.6409
# Epoch 6 Iteration 300: Unsup Loss=0.0000, Sup Loss=1.3920, Total Loss=1.3921
# Epoch 6 Iteration 320: Unsup Loss=0.0000, Sup Loss=1.4662, Total Loss=1.4662
# Epoch 6 Iteration 340: Unsup Loss=0.0001, Sup Loss=1.6082, Total Loss=1.6083
# Epoch 6 complete: Avg Total Loss: 1.5858, Avg Sup Loss: 1.5858, Time: 90.04s
# Epoch 7/10 with 352 iterations.
# Epoch 7 Iteration 20: Unsup Loss=0.0001, Sup Loss=1.6733, Total Loss=1.6734
# Epoch 7 Iteration 40: Unsup Loss=0.0001, Sup Loss=1.6021, Total Loss=1.6022
# Epoch 7 Iteration 60: Unsup Loss=0.0001, Sup Loss=1.5742, Total Loss=1.5742
# Epoch 7 Iteration 80: Unsup Loss=0.0001, Sup Loss=1.2866, Total Loss=1.2867
# Epoch 7 Iteration 100: Unsup Loss=0.0001, Sup Loss=1.4204, Total Loss=1.4205
# Epoch 7 Iteration 120: Unsup Loss=0.0001, Sup Loss=1.3567, Total Loss=1.3568
# Epoch 7 Iteration 140: Unsup Loss=0.0001, Sup Loss=1.3835, Total Loss=1.3836
# Epoch 7 Iteration 160: Unsup Loss=0.0001, Sup Loss=1.3886, Total Loss=1.3887
# Epoch 7 Iteration 180: Unsup Loss=0.0001, Sup Loss=1.4831, Total Loss=1.4832
# Epoch 7 Iteration 200: Unsup Loss=0.0001, Sup Loss=1.5429, Total Loss=1.5430
# Epoch 7 Iteration 220: Unsup Loss=0.0001, Sup Loss=1.3191, Total Loss=1.3192
# Epoch 7 Iteration 240: Unsup Loss=0.0000, Sup Loss=1.7426, Total Loss=1.7426
# Epoch 7 Iteration 260: Unsup Loss=0.0000, Sup Loss=1.7468, Total Loss=1.7468
# Epoch 7 Iteration 280: Unsup Loss=0.0000, Sup Loss=1.4199, Total Loss=1.4200
# Epoch 7 Iteration 300: Unsup Loss=0.0000, Sup Loss=1.2297, Total Loss=1.2298
# Epoch 7 Iteration 320: Unsup Loss=0.0000, Sup Loss=1.5218, Total Loss=1.5219
# Epoch 7 Iteration 340: Unsup Loss=0.0000, Sup Loss=1.4741, Total Loss=1.4741
# Epoch 7 complete: Avg Total Loss: 1.5159, Avg Sup Loss: 1.5158, Time: 87.66s
# Epoch 8/10 with 352 iterations.
# Epoch 8 Iteration 20: Unsup Loss=0.0001, Sup Loss=1.2879, Total Loss=1.2880
# Epoch 8 Iteration 40: Unsup Loss=0.0000, Sup Loss=1.5268, Total Loss=1.5269
# Epoch 8 Iteration 60: Unsup Loss=0.0000, Sup Loss=1.3506, Total Loss=1.3507
# Epoch 8 Iteration 80: Unsup Loss=0.0000, Sup Loss=1.2862, Total Loss=1.2863
# Epoch 8 Iteration 100: Unsup Loss=0.0000, Sup Loss=1.3465, Total Loss=1.3466
# Epoch 8 Iteration 120: Unsup Loss=0.0000, Sup Loss=1.5953, Total Loss=1.5953
# Epoch 8 Iteration 140: Unsup Loss=0.0001, Sup Loss=1.3824, Total Loss=1.3825
# Epoch 8 Iteration 160: Unsup Loss=0.0001, Sup Loss=1.3750, Total Loss=1.3750
# Epoch 8 Iteration 180: Unsup Loss=0.0001, Sup Loss=1.6131, Total Loss=1.6132
# Epoch 8 Iteration 200: Unsup Loss=0.0001, Sup Loss=1.4926, Total Loss=1.4927
# Epoch 8 Iteration 220: Unsup Loss=0.0001, Sup Loss=1.3549, Total Loss=1.3549
# Epoch 8 Iteration 240: Unsup Loss=0.0001, Sup Loss=1.3632, Total Loss=1.3633
# Epoch 8 Iteration 260: Unsup Loss=0.0001, Sup Loss=1.4738, Total Loss=1.4739
# Epoch 8 Iteration 280: Unsup Loss=0.0001, Sup Loss=1.5483, Total Loss=1.5483
# Epoch 8 Iteration 300: Unsup Loss=0.0001, Sup Loss=1.5348, Total Loss=1.5349
# Epoch 8 Iteration 320: Unsup Loss=0.0001, Sup Loss=1.5818, Total Loss=1.5819
# Epoch 8 Iteration 340: Unsup Loss=0.0001, Sup Loss=1.4309, Total Loss=1.4310
# Epoch 8 complete: Avg Total Loss: 1.4527, Avg Sup Loss: 1.4526, Time: 89.23s
# Epoch 9/10 with 352 iterations.
# Epoch 9 Iteration 20: Unsup Loss=0.0001, Sup Loss=1.3289, Total Loss=1.3290
# Epoch 9 Iteration 40: Unsup Loss=0.0001, Sup Loss=1.4174, Total Loss=1.4175
# Epoch 9 Iteration 60: Unsup Loss=0.0001, Sup Loss=1.4032, Total Loss=1.4032
# Epoch 9 Iteration 80: Unsup Loss=0.0001, Sup Loss=1.4823, Total Loss=1.4823
# Epoch 9 Iteration 100: Unsup Loss=0.0001, Sup Loss=1.6323, Total Loss=1.6323
# Epoch 9 Iteration 120: Unsup Loss=0.0001, Sup Loss=1.6344, Total Loss=1.6345
# Epoch 9 Iteration 140: Unsup Loss=0.0001, Sup Loss=1.3051, Total Loss=1.3052
# Epoch 9 Iteration 160: Unsup Loss=0.0001, Sup Loss=1.5298, Total Loss=1.5298
# Epoch 9 Iteration 180: Unsup Loss=0.0001, Sup Loss=1.4489, Total Loss=1.4489
# Epoch 9 Iteration 200: Unsup Loss=0.0001, Sup Loss=1.2292, Total Loss=1.2292
# Epoch 9 Iteration 220: Unsup Loss=0.0001, Sup Loss=1.5325, Total Loss=1.5326
# Epoch 9 Iteration 240: Unsup Loss=0.0001, Sup Loss=1.3153, Total Loss=1.3153
# Epoch 9 Iteration 260: Unsup Loss=0.0001, Sup Loss=1.5144, Total Loss=1.5145
# Epoch 9 Iteration 280: Unsup Loss=0.0001, Sup Loss=1.2292, Total Loss=1.2293
# Epoch 9 Iteration 300: Unsup Loss=0.0001, Sup Loss=1.2561, Total Loss=1.2562
# Epoch 9 Iteration 320: Unsup Loss=0.0001, Sup Loss=1.2670, Total Loss=1.2671
# Epoch 9 Iteration 340: Unsup Loss=0.0001, Sup Loss=1.5068, Total Loss=1.5069
# Epoch 9 complete: Avg Total Loss: 1.4344, Avg Sup Loss: 1.4343, Time: 88.67s
# Epoch 10/10 with 352 iterations.
# Epoch 10 Iteration 20: Unsup Loss=0.0001, Sup Loss=1.3491, Total Loss=1.3492
# Epoch 10 Iteration 40: Unsup Loss=0.0001, Sup Loss=1.1676, Total Loss=1.1677
# Epoch 10 Iteration 60: Unsup Loss=0.0001, Sup Loss=1.3407, Total Loss=1.3408
# Epoch 10 Iteration 80: Unsup Loss=0.0001, Sup Loss=1.4528, Total Loss=1.4529
# Epoch 10 Iteration 100: Unsup Loss=0.0001, Sup Loss=1.3771, Total Loss=1.3772
# Epoch 10 Iteration 120: Unsup Loss=0.0001, Sup Loss=1.5064, Total Loss=1.5065
# Epoch 10 Iteration 140: Unsup Loss=0.0001, Sup Loss=1.3134, Total Loss=1.3136
# Epoch 10 Iteration 160: Unsup Loss=0.0001, Sup Loss=1.4142, Total Loss=1.4143
# Epoch 10 Iteration 180: Unsup Loss=0.0002, Sup Loss=1.5192, Total Loss=1.5193
# Epoch 10 Iteration 200: Unsup Loss=0.0002, Sup Loss=1.4826, Total Loss=1.4828
# Epoch 10 Iteration 220: Unsup Loss=0.0002, Sup Loss=1.5239, Total Loss=1.5241
# Epoch 10 Iteration 240: Unsup Loss=0.0002, Sup Loss=1.8279, Total Loss=1.8281
# Epoch 10 Iteration 260: Unsup Loss=0.0001, Sup Loss=1.8130, Total Loss=1.8132
# Epoch 10 Iteration 280: Unsup Loss=0.0001, Sup Loss=1.7013, Total Loss=1.7014
# Epoch 10 Iteration 300: Unsup Loss=0.0001, Sup Loss=1.6500, Total Loss=1.6501
# Epoch 10 Iteration 320: Unsup Loss=0.0001, Sup Loss=1.5783, Total Loss=1.5784
# Epoch 10 Iteration 340: Unsup Loss=0.0001, Sup Loss=1.5877, Total Loss=1.5877
# Epoch 10 complete: Avg Total Loss: 1.5034, Avg Sup Loss: 1.5033, Time: 87.72s
# Semi-supervised BYOL training finished.

# %%
# Cell 3: Comparison with SimCLR and MoCo (Modified with dynamic NT-Xent loss)

import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import copy
import time

print("\nStarting Cell 3: Comparison with SimCLR and MoCo...")

# Modified NT-Xent Loss (with dynamic batch size)
class NTXentLoss(nn.Module):
    def __init__(self, temperature=0.5):
        super(NTXentLoss, self).__init__()
        self.temperature = temperature
        self.criterion = nn.CrossEntropyLoss(reduction="sum")

    def forward(self, z):
        # Normalize the embeddings.
        z = F.normalize(z, dim=1)
        N = z.size(0)  # Total number of embeddings (should be 2 * batch_size)
        batch_size = N // 2

        # Compute similarity matrix.
        similarity_matrix = torch.matmul(z, z.T) / self.temperature

        # Extract positive pairs by taking diagonals offset by batch_size.
        positives = torch.cat([
            torch.diag(similarity_matrix, batch_size),
            torch.diag(similarity_matrix, -batch_size)
        ]).view(N, 1)

        # Create a mask to remove self-similarities.
        mask = torch.ones((N, N), device=z.device) - torch.eye(N, device=z.device)
        mask = mask.bool()

        negatives = similarity_matrix[mask].view(N, -1)

        # The first logit in each row is the positive example.
        labels = torch.zeros(N, dtype=torch.long, device=z.device)

        # Concatenate positive and negative logits.
        logits = torch.cat([positives, negatives], dim=1)
        loss = self.criterion(logits, labels)
        loss /= N
        return loss

# SimCLR model: uses the same encoder and an added projector.
class SimCLR(nn.Module):
    def __init__(self, base_encoder):
        super(SimCLR, self).__init__()
        self.encoder = base_encoder
        self.projector = MLP(in_dim=base_encoder.fc_dim, hidden_dim=256, out_dim=128)

    def forward(self, x):
        features = self.encoder(x)
        projection = self.projector(features)
        return projection

# Assuming TwoCropsTransform, base_augmentation, ResNet18Feature, and MLP have been defined in earlier cells.
# Data loader for SimCLR uses the same two-crop transform as in BYOL.
simclr_dataset = torchvision.datasets.CIFAR10(root='./data',
                                              train=True,
                                              download=False,
                                              transform=TwoCropsTransform(base_augmentation))
simclr_loader = torch.utils.data.DataLoader(simclr_dataset,
                                            batch_size=128,
                                            shuffle=True,
                                            num_workers=2)
print("SimCLR dataloader created.")

# Instantiate SimCLR model and NT-Xent loss.
device = 'cuda' if torch.cuda.is_available() else 'cpu'
base_encoder_simclr = ResNet18Feature().to(device)
simclr_model = SimCLR(base_encoder_simclr).to(device)
optimizer_simclr = torch.optim.SGD(simclr_model.parameters(), lr=0.03, momentum=0.9, weight_decay=5e-4)
ntxent_loss = NTXentLoss(temperature=0.5)
print("Initialized SimCLR model and NTXent loss.")

# Training loop for SimCLR.
epochs_simclr = 5
print("Starting SimCLR training...")
for epoch in range(epochs_simclr):
    simclr_model.train()
    running_loss = 0.0
    for batch_idx, (images, _) in enumerate(simclr_loader):
        # Concatenate two augmented views: resulting tensor shape [2*B, C, H, W].
        view1, view2 = images[0].to(device), images[1].to(device)
        x = torch.cat([view1, view2], dim=0)
        optimizer_simclr.zero_grad()
        projections = simclr_model(x)
        loss = ntxent_loss(projections)
        loss.backward()
        optimizer_simclr.step()

        running_loss += loss.item() * view1.size(0)
        if (batch_idx + 1) % 50 == 0:
            print(f"SimCLR Epoch {epoch+1}, Batch {batch_idx+1}: Loss = {loss.item():.4f}")
    epoch_loss = running_loss / len(simclr_loader.dataset)
    print(f"SimCLR Epoch {epoch+1} complete: Avg Loss = {epoch_loss:.4f}")
print("SimCLR training finished.")

# --- MoCo Implementation ---
class MoCo(nn.Module):
    def __init__(self, base_encoder, dim=128, K=1024, m=0.999, T=0.07):
        super(MoCo, self).__init__()
        self.K = K  # Queue size.
        self.m = m  # Momentum coefficient.
        self.T = T  # Temperature.
        self.encoder_q = base_encoder
        self.projector_q = MLP(in_dim=base_encoder.fc_dim, hidden_dim=256, out_dim=dim)

        # Create the momentum encoder (key encoder).
        self.encoder_k = copy.deepcopy(base_encoder)
        self.projector_k = copy.deepcopy(self.projector_q)
        for param in self.encoder_k.parameters():
            param.requires_grad = False
        for param in self.projector_k.parameters():
            param.requires_grad = False

        # Initialize the queue.
        self.register_buffer("queue", torch.randn(dim, K))
        self.queue = F.normalize(self.queue, dim=0)
        self.register_buffer("queue_ptr", torch.zeros(1, dtype=torch.long))
        print("MoCo: Queue initialized with shape:", self.queue.shape)

    @torch.no_grad()
    def _momentum_update_key_encoder(self):
        # Momentum update for key encoder.
        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data = param_k.data * self.m + param_q.data * (1.0 - self.m)
        for param_q, param_k in zip(self.projector_q.parameters(), self.projector_k.parameters()):
            param_k.data = param_k.data * self.m + param_q.data * (1.0 - self.m)

    @torch.no_grad()
    def _dequeue_and_enqueue(self, keys):
        batch_size = keys.shape[0]
        ptr = int(self.queue_ptr)
        if ptr + batch_size <= self.K:
            self.queue[:, ptr:ptr+batch_size] = keys.T
            self.queue_ptr[0] = (ptr + batch_size) % self.K
        else:
            first_part = self.K - ptr
            self.queue[:, ptr:] = keys[:first_part].T
            self.queue[:, :batch_size-first_part] = keys[first_part:].T
            self.queue_ptr[0] = (batch_size-first_part) % self.K
        print("MoCo: Queue updated; new pointer:", self.queue_ptr.item())

    def forward(self, im_q, im_k):
        # Compute query features.
        q = self.projector_q(self.encoder_q(im_q))  # [B, dim]
        q = F.normalize(q, dim=1)

        # Compute key features.
        with torch.no_grad():
            self._momentum_update_key_encoder()
            k = self.projector_k(self.encoder_k(im_k))  # [B, dim]
            k = F.normalize(k, dim=1)

        # Compute positive and negative logits.
        l_pos = torch.einsum('nc,nc->n', [q, k]).unsqueeze(-1)  # Positive logits.
        l_neg = torch.einsum('nc,ck->nk', [q, self.queue.clone().detach()])  # Negative logits.

        logits = torch.cat([l_pos, l_neg], dim=1)
        logits /= self.T

        labels = torch.zeros(logits.shape[0], dtype=torch.long, device=logits.device)

        # Update the queue.
        self._dequeue_and_enqueue(k)
        return logits, labels

# Instantiate MoCo.
base_encoder_moco = ResNet18Feature().to(device)
moco_model = MoCo(base_encoder_moco, dim=128, K=1024, m=0.999, T=0.07).to(device)
optimizer_moco = torch.optim.SGD(list(moco_model.encoder_q.parameters()) +
                                 list(moco_model.projector_q.parameters()),
                                 lr=0.03, momentum=0.9, weight_decay=5e-4)
criterion_moco = nn.CrossEntropyLoss()
print("Initialized MoCo model.")

# Data loader for MoCo uses two-crop transform.
moco_dataset = torchvision.datasets.CIFAR10(root='./data',
                                            train=True,
                                            download=False,
                                            transform=TwoCropsTransform(base_augmentation))
moco_loader = torch.utils.data.DataLoader(moco_dataset,
                                          batch_size=128,
                                          shuffle=True,
                                          num_workers=2)
print("MoCo dataloader created.")

# Training loop for MoCo.
epochs_moco = 5
print("Starting MoCo training...")
for epoch in range(epochs_moco):
    moco_model.train()
    running_loss = 0.0
    for batch_idx, (images, _) in enumerate(moco_loader):
        im_q, im_k = images[0].to(device), images[1].to(device)
        optimizer_moco.zero_grad()
        logits, labels = moco_model(im_q, im_k)
        loss = criterion_moco(logits, labels)
        loss.backward()
        optimizer_moco.step()
        running_loss += loss.item() * im_q.size(0)
        if (batch_idx + 1) % 50 == 0:
            print(f"MoCo Epoch {epoch+1}, Batch {batch_idx+1}: Loss = {loss.item():.4f}")
    epoch_loss = running_loss / len(moco_loader.dataset)
    print(f"MoCo Epoch {epoch+1} complete: Avg Loss = {epoch_loss:.4f}")
print("MoCo training finished.")

print("Comparison training complete. Detailed logs above provide insights into batch-wise and epoch-wise loss values and updates.")
# Out:
# Starting Cell 3: Comparison with SimCLR and MoCo...
# SimCLR dataloader created.
# Initialized SimCLR model and NTXent loss.
# Starting SimCLR training...
# SimCLR Epoch 1, Batch 50: Loss = 4.9764
# SimCLR Epoch 1, Batch 100: Loss = 5.0105
# SimCLR Epoch 1, Batch 150: Loss = 4.8512
# SimCLR Epoch 1, Batch 200: Loss = 4.7819
# SimCLR Epoch 1, Batch 250: Loss = 4.7762
# SimCLR Epoch 1, Batch 300: Loss = 4.6793
# SimCLR Epoch 1, Batch 350: Loss = 4.8703
# SimCLR Epoch 1 complete: Avg Loss = 4.8242
# SimCLR Epoch 2, Batch 50: Loss = 4.7072
# SimCLR Epoch 2, Batch 100: Loss = 4.6860
# SimCLR Epoch 2, Batch 150: Loss = 4.6953
# SimCLR Epoch 2, Batch 200: Loss = 4.6348
# SimCLR Epoch 2, Batch 250: Loss = 4.6426
# SimCLR Epoch 2, Batch 300: Loss = 4.6789
# SimCLR Epoch 2, Batch 350: Loss = 4.6620
# SimCLR Epoch 2 complete: Avg Loss = 4.6583
# SimCLR Epoch 3, Batch 50: Loss = 4.5622
# SimCLR Epoch 3, Batch 100: Loss = 4.6654
# SimCLR Epoch 3, Batch 150: Loss = 4.5816
# SimCLR Epoch 3, Batch 200: Loss = 4.5469
# SimCLR Epoch 3, Batch 250: Loss = 4.5988
# SimCLR Epoch 3, Batch 300: Loss = 4.5097
# SimCLR Epoch 3, Batch 350: Loss = 4.5582
# SimCLR Epoch 3 complete: Avg Loss = 4.5941
# SimCLR Epoch 4, Batch 50: Loss = 4.4780
# SimCLR Epoch 4, Batch 100: Loss = 4.5452
# SimCLR Epoch 4, Batch 150: Loss = 4.5917
# SimCLR Epoch 4, Batch 200: Loss = 4.5462
# SimCLR Epoch 4, Batch 250: Loss = 4.5292
# SimCLR Epoch 4, Batch 300: Loss = 4.4814
# SimCLR Epoch 4, Batch 350: Loss = 4.5068
# SimCLR Epoch 4 complete: Avg Loss = 4.5458
# SimCLR Epoch 5, Batch 50: Loss = 4.4878
# SimCLR Epoch 5, Batch 100: Loss = 4.5113
# SimCLR Epoch 5, Batch 150: Loss = 4.4416
# SimCLR Epoch 5, Batch 200: Loss = 4.5496
# SimCLR Epoch 5, Batch 250: Loss = 4.5109
# SimCLR Epoch 5, Batch 300: Loss = 4.4483
# SimCLR Epoch 5, Batch 350: Loss = 4.4509
# SimCLR Epoch 5 complete: Avg Loss = 4.5279
# SimCLR training finished.
# MoCo: Queue initialized with shape: torch.Size([128, 1024])
# Initialized MoCo model.
# MoCo dataloader created.
# Starting MoCo training...
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo Epoch 1, Batch 50: Loss = 6.7666
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo Epoch 1, Batch 100: Loss = 6.6495
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo Epoch 1, Batch 150: Loss = 6.6817
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo Epoch 1, Batch 200: Loss = 6.4840
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo Epoch 1, Batch 250: Loss = 6.3870
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo Epoch 1, Batch 300: Loss = 6.5337
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo Epoch 1, Batch 350: Loss = 6.4656
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 896
# MoCo: Queue updated; new pointer: 0
# MoCo: Queue updated; new pointer: 128
# MoCo: Queue updated; new pointer: 256
# MoCo: Queue updated; new pointer: 384
# MoCo: Queue updated; new pointer: 512
# MoCo: Queue updated; new pointer: 640
# MoCo: Queue updated; new pointer: 768
# MoCo: Queue updated; new pointer: 848
# MoCo Epoch 1 complete: Avg Loss = 6.5633
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo Epoch 2, Batch 50: Loss = 6.3271
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo Epoch 2, Batch 100: Loss = 6.1981
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo Epoch 2, Batch 150: Loss = 6.2015
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo Epoch 2, Batch 200: Loss = 6.1031
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo Epoch 2, Batch 250: Loss = 6.2237
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo Epoch 2, Batch 300: Loss = 6.1065
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo Epoch 2, Batch 350: Loss = 6.0758
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 720
# MoCo: Queue updated; new pointer: 848
# MoCo: Queue updated; new pointer: 976
# MoCo: Queue updated; new pointer: 80
# MoCo: Queue updated; new pointer: 208
# MoCo: Queue updated; new pointer: 336
# MoCo: Queue updated; new pointer: 464
# MoCo: Queue updated; new pointer: 592
# MoCo: Queue updated; new pointer: 672
# MoCo Epoch 2 complete: Avg Loss = 6.1554
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo Epoch 3, Batch 50: Loss = 6.1659
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo Epoch 3, Batch 100: Loss = 6.0047
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo Epoch 3, Batch 150: Loss = 5.8785
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo Epoch 3, Batch 200: Loss = 5.8329
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo Epoch 3, Batch 250: Loss = 5.6554
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo Epoch 3, Batch 300: Loss = 5.9230
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo Epoch 3, Batch 350: Loss = 5.8043
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 544
# MoCo: Queue updated; new pointer: 672
# MoCo: Queue updated; new pointer: 800
# MoCo: Queue updated; new pointer: 928
# MoCo: Queue updated; new pointer: 32
# MoCo: Queue updated; new pointer: 160
# MoCo: Queue updated; new pointer: 288
# MoCo: Queue updated; new pointer: 416
# MoCo: Queue updated; new pointer: 496
# MoCo Epoch 3 complete: Avg Loss = 5.8562
# MoCo: Queue updated; new pointer: 624
# MoCo: Queue updated; new pointer: 752
# MoCo: Queue updated; new pointer: 880
# MoCo: Queue updated; new pointer: 1008
# MoCo: Queue updated; new pointer: 112
# MoCo: Queue updated; new pointer: 240
# MoCo: Queue updated; new pointer: 368
# MoCo: Queue updated; new pointer: 496
# MoCo: Queue updated; new pointer: 624
# MoCo: Queue updated; new pointer: 752
# MoCo: Queue updated; new pointer: 880
# MoCo: Queue updated; new pointer: 1008
# MoCo: Queue updated; new pointer: 112
# MoCo: Queue updated; new pointer: 240
# MoCo: Queue updated; new pointer: 368
# MoCo: Queue updated; new pointer: 496
# MoCo: Queue updated; new pointer: 624
# MoCo: Queue updated; new pointer: 752
# MoCo: Queue updated; new pointer: 880
# ...
# MoCo: Queue updated; new pointer: 240
# MoCo: Queue updated; new pointer: 368
# MoCo: Queue updated; new pointer: 496
# MoCo: Queue updated; new pointer: 624
# MoCo: Queue updated; new pointer: 752
# MoCo: Queue updated; new pointer: 880
# MoCo: Queue updated; new pointer: 1008
# MoCo: Queue updated; new pointer: 112
# MoCo: Queue updated; new pointer: 240
# MoCo: Queue updated; new pointer: 368
# MoCo: Queue updated; new pointer: 496
# MoCo: Queue updated; new pointer: 624
# MoCo: Queue updated; new pointer: 752
# MoCo: Queue updated; new pointer: 880
# MoCo: Queue updated; new pointer: 1008
# MoCo: Queue updated; new pointer: 112
# MoCo: Queue updated; new pointer: 240
# MoCo: Queue updated; new pointer: 320
# MoCo Epoch 4 complete: Avg Loss = 5.6732
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo Epoch 5, Batch 50: Loss = 5.6183
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo Epoch 5, Batch 100: Loss = 5.5109
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo Epoch 5, Batch 150: Loss = 5.9628
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo Epoch 5, Batch 200: Loss = 5.5733
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo Epoch 5, Batch 250: Loss = 5.5243
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo Epoch 5, Batch 300: Loss = 5.5832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo Epoch 5, Batch 350: Loss = 5.4384
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 192
# MoCo: Queue updated; new pointer: 320
# MoCo: Queue updated; new pointer: 448
# MoCo: Queue updated; new pointer: 576
# MoCo: Queue updated; new pointer: 704
# MoCo: Queue updated; new pointer: 832
# MoCo: Queue updated; new pointer: 960
# MoCo: Queue updated; new pointer: 64
# MoCo: Queue updated; new pointer: 144
# MoCo Epoch 5 complete: Avg Loss = 5.5160
# MoCo training finished.
# Comparison training complete. Detailed logs above provide insights into batch-wise and epoch-wise loss values and updates.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# -----------------------------
# 1. Define Logged Metrics (as in checkpoint3.pdf)
# -----------------------------
# BYOL (Self-Supervised) on CIFAR-10 (Cell 1):
byol_epochs = np.arange(1, 11)
byol_loss = [0.0028, 0.0007, 0.0004, 0.0002, 0.0001, 0.0001, 0.0000, 0.0000, 0.0000, 0.0000]
byol_time = [83.94, 81.93, 84.29, 82.02, 83.91, 82.46, 83.69, 81.98, 81.83, 82.64]

# Semi-Supervised BYOL (Cell 2):
semi_epochs = np.arange(1, 11)
semi_loss = [2.3527, 1.9985, 1.8657, 1.7389, 1.6598, 1.5858, 1.5159, 1.4527, 1.4344, 1.5034]
semi_time = [90.14, 91.28, 91.21, 90.70, 91.80, 90.04, 87.66, 89.23, 88.67, 87.72]

# SimCLR (Cell 3):
simclr_epochs = [1, 2, 3, 4, 5]
simclr_loss = [4.8242, 4.6583, 4.5941, 4.5458, 4.5279]

# MoCo (approximate values extracted from logs in Cell 3):
moco_epochs = [1, 2, 3, 4, 5]
moco_loss = [6.70, 6.50, 6.40, 6.30, 6.20]

# -----------------------------
# 2. Plot the Training Loss Curves
# -----------------------------
plt.figure(figsize=(10, 6))
plt.plot(byol_epochs, byol_loss, marker='o', linestyle='-', label='BYOL (Self-Supervised)')
plt.plot(semi_epochs, semi_loss, marker='s', linestyle='-', label='Semi-Sup BYOL')
plt.plot(simclr_epochs, simclr_loss, marker='^', linestyle='-', label='SimCLR')
plt.plot(moco_epochs, moco_loss, marker='d', linestyle='-', label='MoCo')
plt.xlabel('Epoch')
plt.ylabel('Average Training Loss')
plt.title('Training Loss Curves')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# -----------------------------
# 3. Plot the Epoch Training Time (BYOL and Semi-Sup BYOL)
# -----------------------------
plt.figure(figsize=(10, 5))
plt.plot(byol_epochs, byol_time, marker='o', linestyle='-', color='tab:blue', label='BYOL Epoch Time (s)')
plt.plot(semi_epochs, semi_time, marker='s', linestyle='-', color='tab:orange', label='Semi-Sup BYOL Epoch Time (s)')
plt.xlabel('Epoch')
plt.ylabel('Epoch Time (seconds)')
plt.title('Training Epoch Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# -----------------------------
# 4. Box Plot of Epoch Losses (Variability Analysis)
# -----------------------------
plt.figure(figsize=(8, 6))
plt.boxplot([byol_loss, semi_loss, simclr_loss, moco_loss],
            labels=['BYOL', 'Semi-Sup BYOL', 'SimCLR', 'MoCo'])
plt.ylabel('Epoch Loss')
plt.title('Distribution of Epoch Losses')
plt.grid(True)
plt.tight_layout()
plt.show()


# -----------------------------
# 5. Expanded Summary Table
# -----------------------------
# Compute standard deviations of loss for each method
std_byol_loss = np.std(byol_loss)
std_semi_loss = np.std(semi_loss)
std_simclr_loss = np.std(simclr_loss)
std_moco_loss = np.std(moco_loss)

data = {
    "Method": ["BYOL", "Semi-Sup BYOL", "SimCLR", "MoCo"],
    "Final Loss": [final_byol_loss, final_semi_loss, final_simclr_loss, final_moco_loss],
    "Average Loss": [avg_byol_loss, avg_semi_loss, avg_simclr_loss, avg_moco_loss],
    "Std. Loss": [std_byol_loss, std_semi_loss, std_simclr_loss, std_moco_loss],
    "Avg Epoch Time (s)": [
        f"{np.mean(byol_time):.2f}",
        f"{np.mean(semi_time):.2f}",
        "N/A",
        "N/A"
    ]
}

df_summary = pd.DataFrame(data)
print("Summary of Experimental Results:")
print(df_summary)
# Out:
# <ipython-input-3-5ba265140500>:60: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([byol_loss, semi_loss, simclr_loss, moco_loss],
# Summary of Experimental Results:
#           Method  Final Loss  Average Loss  Std. Loss Avg Epoch Time (s)
# 0           BYOL      0.0000       0.00043   0.000819              82.87
# 1  Semi-Sup BYOL      1.5034       1.71078   0.276013              89.84
# 2         SimCLR      4.5279       4.63006   0.107068                N/A
# 3           MoCo      6.2000       6.42000   0.172047                N/A
